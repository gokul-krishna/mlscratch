# %%
import numpy as np

# %%
from sklearn.datasets import make_blobs

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 6]

# %%
X, y = make_blobs(n_samples=10, n_features=2, centers=2, cluster_std=2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', lw=1)

# %%
W = np.array([-3, 3])

# %%
W.shape
# Out:
# (2,)

# %%
np.dot(W, np.vstack([np.linspace(-10, 2, 100), np.ones(100)]))
# Out:
# array([33.        , 32.63636364, 32.27272727, 31.90909091, 31.54545455,
#        31.18181818, 30.81818182, 30.45454545, 30.09090909, 29.72727273,
#        29.36363636, 29.        , 28.63636364, 28.27272727, 27.90909091,
#        27.54545455, 27.18181818, 26.81818182, 26.45454545, 26.09090909,
#        25.72727273, 25.36363636, 25.        , 24.63636364, 24.27272727,
#        23.90909091, 23.54545455, 23.18181818, 22.81818182, 22.45454545,
#        22.09090909, 21.72727273, 21.36363636, 21.        , 20.63636364,
#        20.27272727, 19.90909091, 19.54545455, 19.18181818, 18.81818182,
#        18.45454545, 18.09090909, 17.72727273, 17.36363636, 17.        ,
#        16.63636364, 16.27272727, 15.90909091, 15.54545455, 15.18181818,
#        14.81818182, 14.45454545, 14.09090909, 13.72727273, 13.36363636,
#        13.        , 12.63636364, 12.27272727, 11.90909091, 11.54545455,
#        11.18181818, 10.81818182, 10.45454545, 10.09090909,  9.72727273,
# ...

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', lw=1)

plt.scatter(np.linspace(-10, 2, 100),
            np.dot(W, np.vstack([np.linspace(-10, 2, 100), np.ones(100)])))

# %%
+ np.dot(W.T, W)
# Out:
# 18
